# %% [markdown]
# ### Configure Jupyter to run plot widgets and import necesssary packages

# %%
! jupyter nbextension enable --py --sys-prefix qgrid
! jupyter nbextension enable --py --sys-prefix widgetsnbextension
! jupyter nbextension enable --py --sys-prefix ipympl
# %pip install Pyriod
# Out:
# Enabling notebook extension qgrid/extension...
#       - Validating: OK
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK
# Enabling notebook extension jupyter-matplotlib/extension...
#       - Validating: OK
# Requirement already satisfied: Pyriod in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (0.1.10)
# Requirement already satisfied: astropy<5.0 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from Pyriod) (4.3.1)
# Requirement already satisfied: lmfit>=1.0 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from Pyriod) (1.0.3)
# Requirement already satisfied: ipyfilechooser>=0.3.5 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from Pyriod) (0.6.0)
# Requirement already satisfied: ipywidgets>=7.5 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from Pyriod) (7.6.5)
# Requirement already satisfied: gh-md-to-html in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from Pyriod) (1.21.2)
# Requirement already satisfied: pandas>=1.0 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from Pyriod) (1.3.4)
# Requirement already satisfied: numpy>=1.11 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from Pyriod) (1.20.3)
# Requirement already satisfied: ipympl>=0.7 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from Pyriod) (0.8.8)
# Requirement already satisfied: bs4 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from Pyriod) (0.0.1)
# Requirement already satisfied: matplotlib>=3.4 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from Pyriod) (3.4.3)
# Requirement already satisfied: lightkurve>=2.0.10 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from Pyriod) (2.0.11)
# Requirement already satisfied: qgrid>=1.3.1 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from Pyriod) (1.3.1)
# Requirement already satisfied: scipy>=0.19 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from Pyriod) (1.7.1)
# Requirement already satisfied: pyerfa>=1.7.3 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from astropy<5.0->Pyriod) (2.0.0)
# Requirement already satisfied: ipython<9 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from ipympl>=0.7->Pyriod) (7.29.0)
# Requirement already satisfied: pillow in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from ipympl>=0.7->Pyriod) (8.4.0)
# Requirement already satisfied: ipython-genutils in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from ipympl>=0.7->Pyriod) (0.2.0)
# Requirement already satisfied: traitlets<6 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from ipympl>=0.7->Pyriod) (5.1.0)
# Requirement already satisfied: backcall in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from ipython<9->ipympl>=0.7->Pyriod) (0.2.0)
# Requirement already satisfied: pygments in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from ipython<9->ipympl>=0.7->Pyriod) (2.10.0)
# Requirement already satisfied: decorator in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from ipython<9->ipympl>=0.7->Pyriod) (5.1.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from ipython<9->ipympl>=0.7->Pyriod) (3.0.20)
# Requirement already satisfied: matplotlib-inline in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from ipython<9->ipympl>=0.7->Pyriod) (0.1.2)
# Requirement already satisfied: appnope in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from ipython<9->ipympl>=0.7->Pyriod) (0.1.2)
# Requirement already satisfied: pexpect>4.3 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from ipython<9->ipympl>=0.7->Pyriod) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from ipython<9->ipympl>=0.7->Pyriod) (58.0.4)
# Requirement already satisfied: pickleshare in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from ipython<9->ipympl>=0.7->Pyriod) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from ipython<9->ipympl>=0.7->Pyriod) (0.18.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.5->Pyriod) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.5->Pyriod) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.5->Pyriod) (5.1.3)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.5->Pyriod) (6.4.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5->Pyriod) (1.4.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5->Pyriod) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5->Pyriod) (6.1.12)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython<9->ipympl>=0.7->Pyriod) (0.8.2)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5->Pyriod) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5->Pyriod) (22.2.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5->Pyriod) (4.8.1)
# Requirement already satisfied: tqdm>=4.25.0 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from lightkurve>=2.0.10->Pyriod) (4.62.3)
# Requirement already satisfied: uncertainties>=3.1.4 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from lightkurve>=2.0.10->Pyriod) (3.1.6)
# Requirement already satisfied: fbpca>=1.0 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from lightkurve>=2.0.10->Pyriod) (1.0)
# Requirement already satisfied: scikit-learn>=0.24.0 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from lightkurve>=2.0.10->Pyriod) (0.24.2)
# Requirement already satisfied: beautifulsoup4>=4.6.0 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from lightkurve>=2.0.10->Pyriod) (4.10.0)
# Requirement already satisfied: memoization>=0.3.1 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from lightkurve>=2.0.10->Pyriod) (0.3.2)
# Requirement already satisfied: patsy>=0.5.0 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from lightkurve>=2.0.10->Pyriod) (0.5.2)
# Requirement already satisfied: oktopus>=0.1.2 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from lightkurve>=2.0.10->Pyriod) (0.1.2)
# Requirement already satisfied: astroquery>=0.3.10 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from lightkurve>=2.0.10->Pyriod) (0.4.5)
# Requirement already satisfied: requests>=2.22.0 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from lightkurve>=2.0.10->Pyriod) (2.26.0)
# Requirement already satisfied: bokeh>=1.0 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from lightkurve>=2.0.10->Pyriod) (2.4.1)
# Requirement already satisfied: html5lib>=0.999 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from astroquery>=0.3.10->lightkurve>=2.0.10->Pyriod) (1.1)
# Requirement already satisfied: keyring>=4.0 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from astroquery>=0.3.10->lightkurve>=2.0.10->Pyriod) (23.1.0)
# Requirement already satisfied: pyvo>=1.1 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from astroquery>=0.3.10->lightkurve>=2.0.10->Pyriod) (1.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4>=4.6.0->lightkurve>=2.0.10->Pyriod) (2.2.1)
# Requirement already satisfied: PyYAML>=3.10 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from bokeh>=1.0->lightkurve>=2.0.10->Pyriod) (6.0)
# Requirement already satisfied: typing-extensions>=3.10.0 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from bokeh>=1.0->lightkurve>=2.0.10->Pyriod) (3.10.0.2)
# Requirement already satisfied: Jinja2>=2.9 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from bokeh>=1.0->lightkurve>=2.0.10->Pyriod) (2.11.3)
# Requirement already satisfied: packaging>=16.8 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from bokeh>=1.0->lightkurve>=2.0.10->Pyriod) (21.0)
# Requirement already satisfied: six>=1.9 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from html5lib>=0.999->astroquery>=0.3.10->lightkurve>=2.0.10->Pyriod) (1.16.0)
# Requirement already satisfied: webencodings in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from html5lib>=0.999->astroquery>=0.3.10->lightkurve>=2.0.10->Pyriod) (0.5.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from Jinja2>=2.9->bokeh>=1.0->lightkurve>=2.0.10->Pyriod) (1.1.1)
# Requirement already satisfied: importlib-metadata>=3.6 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from keyring>=4.0->astroquery>=0.3.10->lightkurve>=2.0.10->Pyriod) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=3.6->keyring>=4.0->astroquery>=0.3.10->lightkurve>=2.0.10->Pyriod) (3.6.0)
# Requirement already satisfied: asteval>=0.9.22 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from lmfit>=1.0->Pyriod) (0.9.26)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.4->Pyriod) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.4->Pyriod) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.4->Pyriod) (3.0.4)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.5->Pyriod) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5->Pyriod) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5->Pyriod) (21.2.0)
# Requirement already satisfied: autograd in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from oktopus>=0.1.2->lightkurve>=2.0.10->Pyriod) (1.3)
# Requirement already satisfied: pytz>=2017.3 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.0->Pyriod) (2021.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython<9->ipympl>=0.7->Pyriod) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<9->ipympl>=0.7->Pyriod) (0.2.5)
# Requirement already satisfied: notebook>=4.0.0 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from qgrid>=1.3.1->Pyriod) (6.4.5)
# Requirement already satisfied: argon2-cffi in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.0.0->qgrid>=1.3.1->Pyriod) (20.1.0)
# Requirement already satisfied: prometheus-client in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.0.0->qgrid>=1.3.1->Pyriod) (0.11.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.0.0->qgrid>=1.3.1->Pyriod) (1.8.0)
# Requirement already satisfied: nbconvert in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.0.0->qgrid>=1.3.1->Pyriod) (6.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.0.0->qgrid>=1.3.1->Pyriod) (0.9.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.22.0->lightkurve>=2.0.10->Pyriod) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.22.0->lightkurve>=2.0.10->Pyriod) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.22.0->lightkurve>=2.0.10->Pyriod) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.22.0->lightkurve>=2.0.10->Pyriod) (2.0.4)
# Requirement already satisfied: joblib>=0.11 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.24.0->lightkurve>=2.0.10->Pyriod) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.24.0->lightkurve>=2.0.10->Pyriod) (2.2.0)
# Requirement already satisfied: future in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from uncertainties>=3.1.4->lightkurve>=2.0.10->Pyriod) (0.18.2)
# Requirement already satisfied: cffi>=1.0.0 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.0.0->qgrid>=1.3.1->Pyriod) (1.14.6)
# Requirement already satisfied: pycparser in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.0.0->qgrid>=1.3.1->Pyriod) (2.20)
# Requirement already satisfied: emoji in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from gh-md-to-html->Pyriod) (1.6.3)
# Requirement already satisfied: shellescape in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from gh-md-to-html->Pyriod) (3.8.1)
# Requirement already satisfied: webcolors in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from gh-md-to-html->Pyriod) (1.11.1)
# Requirement already satisfied: testpath in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.0.0->qgrid>=1.3.1->Pyriod) (0.5.0)
# Requirement already satisfied: jupyterlab-pygments in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.0.0->qgrid>=1.3.1->Pyriod) (0.1.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.0.0->qgrid>=1.3.1->Pyriod) (0.5.3)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.0.0->qgrid>=1.3.1->Pyriod) (0.3)
# Requirement already satisfied: defusedxml in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.0.0->qgrid>=1.3.1->Pyriod) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.0.0->qgrid>=1.3.1->Pyriod) (1.4.3)
# Requirement already satisfied: bleach in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.0.0->qgrid>=1.3.1->Pyriod) (4.0.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.0.0->qgrid>=1.3.1->Pyriod) (0.8.4)
# Requirement already satisfied: async-generator in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.0.0->qgrid>=1.3.1->Pyriod) (1.10)
# Requirement already satisfied: nest-asyncio in /Users/abemankavil/opt/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.0.0->qgrid>=1.3.1->Pyriod) (1.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import lightkurve as lk
import astropy
from Pyriod import Pyriod
# %matplotlib widget

# %%
print(lk.__version__)
print(astropy.__version__)
print(Pyriod.__doc__)
! python --version
# Out:
# 2.0.11
# 4.3.1
# Time series periodic analysis class.
#
#     Attributes
#     ----------
#     lc : lightkurve.LightCurve
#         Time Series to analyze, with flux and time columns
#         (time on scale of days; flux normalized)
#
#
#
# Python 3.9.7

# %% [markdown]
# ### Import your light curve from Lab 4 and initialize Pyriod

# %%
# %matplotlib widget
# Import your light curve from last week. You will need to change the name 
# and/or add a path depending on how you organize your directories
lc_data = np.loadtxt('/Users/abemankavil/Desktop/AST210K/Lab3/DLC.txt')

# Create a LightCurve object. This code assumes your light curve timestamps are in units
# seconds and converts them to days. If your timestamps are not in seconds, modify the 
# conversion factor as needed to ensure your time variable is in units of days.
# I also have written it to normalize your flux such that its mean = 1, which you should 
# have done in Lab 4, but it won't change anything if you already did so.
lc = lk.LightCurve(time=(lc_data[:,0]-min(lc_data[:,0]))/86400, flux=lc_data[:,1]/np.nanmean(lc_data[:,1]))
print('lc:')
print(lc_data)

# Calculate a frequency tolerance in units of uHZ.
# We'll use this to help us chose peaks. Do not select a peak if its distance
# to an already selected peak is smaller than the frequency tolerance.
ftol = 0.5/(max(lc_data[:,0])-min(lc_data[:,0]))*1e6
print(ftol)
# Intilialize Pyriod. Ignore all these plots.
pyriod = Pyriod(lc,amp_unit='percent');
pyriod = Pyriod(lc,amp_unit='relative');
# Out:
# lc:
# [[0.00000000e+00 7.53793185e-01]
#  [1.00000000e+01 7.45234089e-01]
#  [2.00000000e+01 7.37640199e-01]
#  ...
#  [2.15800000e+04 7.38171110e-01]
#  [2.15900000e+04            nan]
#  [2.16000000e+04 7.30010595e-01]]
# 23.148148148148145
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Start up the master Pyriod suite. This is what you'll use for the lab.

# %%
pyriod.Pyriod()
# Out:
# Tab(children=(VBox(children=(HTML(value=''), Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view',…
